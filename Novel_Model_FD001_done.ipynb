# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre-processing

# %%
import numpy as np
import pandas as pd

from IPython.display import display, HTML
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio


import seaborn as sns
from importlib import reload
import matplotlib.pyplot as plt
import matplotlib
import warnings

# Configure Jupyter Notebook
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
pd.set_option('display.expand_frame_repr', False)
# pd.set_option('max_colwidth', -1)
display(HTML("<style>div.output_scroll { height: 35em; }</style>"))

reload(plt)
# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

warnings.filterwarnings('ignore')

# configure plotly graph objects
pio.renderers.default = 'iframe'
# pio.renderers.default = 'vscode'

pio.templates["ck_template"] = go.layout.Template(
    layout_colorway = px.colors.sequential.Viridis,
#     layout_hovermode = 'closest',
#     layout_hoverdistance = -1,
    layout_autosize=False,
    layout_width=800,
    layout_height=600,
    layout_font = dict(family="Calibri Light"),
    layout_title_font = dict(family="Calibri"),
    layout_hoverlabel_font = dict(family="Calibri Light"),
#     plot_bgcolor="white",
)

# pio.templates.default = 'seaborn+ck_template+gridon'
pio.templates.default = 'ck_template+gridon'
# pio.templates.default = 'seaborn+gridon'
# pio.templates
# Out:
# <style>div.output_scroll { height: 35em; }</style>

# %%
index_names = ['engine', 'cycle']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names=[ "(Fan inlet temperature) (◦R)",
"(LPC outlet temperature) (◦R)",
"(HPC outlet temperature) (◦R)",
"(LPT outlet temperature) (◦R)",
"(Fan inlet Pressure) (psia)",
"(bypass-duct pressure) (psia)",
"(HPC outlet pressure) (psia)",
"(Physical fan speed) (rpm)",
"(Physical core speed) (rpm)",
"(Engine pressure ratio(P50/P2)",
"(HPC outlet Static pressure) (psia)",
"(Ratio of fuel flow to Ps30) (pps/psia)",
"(Corrected fan speed) (rpm)",
"(Corrected core speed) (rpm)",
"(Bypass Ratio) ",
"(Burner fuel-air ratio)",
"(Bleed Enthalpy)",
"(Required fan speed)",
"(Required fan conversion speed)",
"(High-pressure turbines Cool air flow)",
"(Low-pressure turbines Cool air flow)" ]
col_names = index_names + setting_names + sensor_names

# %%
df_train = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/train_FD001.txt',sep=r'\s+',header=None,index_col=False,names=col_names)
df_test = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/test_FD001.txt',sep=r'\s+',header=None,index_col=False,names=col_names)
df_test_RUL = pd.read_csv('drive/MyDrive/AeroCare-Aircraft maintenance system/CMaps/RUL_FD001.txt',sep=r'\s+',header=None,index_col=False,names=['RUL'])

# %%
corr = df_train.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(230, 10, as_cmap=True)

# Draw the heatmap with annotation
sns.heatmap(
    corr,
    mask=mask,
    cmap=cmap,
    vmax=.3,
    center=0,
    square=True,
    linewidths=.5,
    cbar_kws={"shrink": .5},
    annot=True,           # <- Add this line
    fmt=".1f"             # <- Format the numbers to 2 decimal places
)

plt.show()

# %%
sens_const_values = []
for feature in list(setting_names + sensor_names):
    try:
        if df_train[feature].min()==df_train[feature].max():
            sens_const_values.append(feature)
    except:
        pass

print(sens_const_values)
df_train.drop(sens_const_values,axis=1,inplace=True)
df_test.drop(sens_const_values,axis=1,inplace=True)
# Out:
# ['setting_3', '(Fan inlet temperature) (◦R)', '(Fan inlet Pressure) (psia)', '(Engine pressure ratio(P50/P2)', '(Burner fuel-air ratio)', '(Required fan speed)', '(Required fan conversion speed)']

# %%
cor_matrix = df_train.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
corr_features = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(corr_features)
df_train.drop(corr_features,axis=1,inplace=True)
df_test.drop(corr_features,axis=1,inplace=True)
# Out:
# ['(Corrected core speed) (rpm)']

# %%
features = list(df_train.columns)

# %%
# check for missing data
for feature in features:
    print(feature + " - " + str(len(df_train[df_train[feature].isna()])))
# Out:
# engine - 0
# cycle - 0
# setting_1 - 0
# setting_2 - 0
# (LPC outlet temperature) (◦R) - 0
# (HPC outlet temperature) (◦R) - 0
# (LPT outlet temperature) (◦R) - 0
# (bypass-duct pressure) (psia) - 0
# (HPC outlet pressure) (psia) - 0
# (Physical fan speed) (rpm) - 0
# (Physical core speed) (rpm) - 0
# (HPC outlet Static pressure) (psia) - 0
# (Ratio of fuel flow to Ps30) (pps/psia) - 0
# (Corrected fan speed) (rpm) - 0
# (Bypass Ratio)  - 0
# (Bleed Enthalpy) - 0
# (High-pressure turbines Cool air flow) - 0
# (Low-pressure turbines Cool air flow) - 0

# %%
# define the maximum life of each engine, as this could be used to obtain the RUL at each point in time of the engine's life
df_train_RUL = df_train.groupby(['engine']).agg({'cycle':'max'})
df_train_RUL.rename(columns={'cycle':'life'},inplace=True)
df_train_RUL.head()
# Out:
#         life
# engine
# 1        192
# 2        287
# 3        179
# 4        189
# 5        269

# %%
df_train=df_train.merge(df_train_RUL,how='left',on=['engine'])

# %%
df_train['RUL']=df_train['life']-df_train['cycle']
df_train.drop(['life'],axis=1,inplace=True)

# the RUL prediction is only useful nearer to the end of the engine's life, therefore we put an upper limit on the RUL
# this is a bit sneaky, since it supposes that the test set has RULs of less than this value, the closer you are
# to the true value, the more accurate the model will be
df_train['RUL'][df_train['RUL']>125]=125
df_train.head()
# Out:
#    engine  cycle  setting_1  setting_2  (LPC outlet temperature) (◦R)  (HPC outlet temperature) (◦R)  (LPT outlet temperature) (◦R)  (bypass-duct pressure) (psia)  (HPC outlet pressure) (psia)  (Physical fan speed) (rpm)  (Physical core speed) (rpm)  (HPC outlet Static pressure) (psia)  (Ratio of fuel flow to Ps30) (pps/psia)  (Corrected fan speed) (rpm)  (Bypass Ratio)   (Bleed Enthalpy)  (High-pressure turbines Cool air flow)  (Low-pressure turbines Cool air flow)  RUL
# 0       1      1    -0.0007    -0.0004                         641.82                        1589.70                        1400.60                          21.61                        554.36                     2388.06                      9046.19                                47.47                                   521.66                      2388.02           8.4195               392                                   39.06                                23.4190  125
# 1       1      2     0.0019    -0.0003                         642.15                        1591.82                        1403.14                          21.61                        553.75                     2388.04                      9044.07                                47.49                                   522.28                      2388.07           8.4318               392                                   39.00                                23.4236  125
# 2       1      3    -0.0043     0.0003                         642.35                        1587.99                        1404.20                          21.61                        554.26                     2388.08                      9052.94                                47.27                                   522.42                      2388.03           8.4178               390                                   38.95                                23.3442  125
# 3       1      4     0.0007     0.0000                         642.35                        1582.79                        1401.87                          21.61                        554.45                     2388.11                      9049.48                                47.13                                   522.86                      2388.08           8.3682               392                                   38.88                                23.3739  125
# 4       1      5    -0.0019    -0.0002                         642.37                        1582.85                        1406.22                          21.61                        554.00                     2388.06                      9055.15                                47.28                                   522.19                      2388.04           8.4294               393                                   38.90                                23.4044  125

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
CONFIG = {
    'WINDOW_SIZE': 30,
    'STRIDE': 1,
    'LSTM_UNITS': [128, 64],
    'DENSE_UNITS': 50,
    'DROPOUT_RATE': 0.3,
    'L2_REG': 0.001,
    'BATCH_SIZE': 64,
    'EPOCHS': 150,
    'LEARNING_RATE': 0.001,
    'PATIENCE': 25,
    'N_SPLITS': 5,
}

print("\nConfiguration:")
for key, value in CONFIG.items():
    print(f"  {key}: {value}")
# Out:
# Configuration:
#   WINDOW_SIZE: 30
#   STRIDE: 1
#   LSTM_UNITS: [128, 64]
#   DENSE_UNITS: 50
#   DROPOUT_RATE: 0.3
#   L2_REG: 0.001
#   BATCH_SIZE: 64
#   EPOCHS: 150
#   LEARNING_RATE: 0.001
#   PATIENCE: 25
#   N_SPLITS: 5

# %%
feature_cols = [col for col in df_train.columns
                if col not in ['engine', 'cycle', 'RUL']]

print(f"✓ Training data: {df_train.shape}")
print(f"✓ Test data: {df_test.shape}")
print(f"✓ Features: {len(feature_cols)}")
# Out:
# ✓ Training data: (20631, 19)
# ✓ Test data: (13096, 18)
# ✓ Features: 16

# %%
scaler = StandardScaler()

df_train_norm = df_train.copy()
df_test_norm = df_test.copy()

# Fit on TRAINING data only
df_train_norm[feature_cols] = scaler.fit_transform(df_train[feature_cols])
df_test_norm[feature_cols] = scaler.transform(df_test[feature_cols])

print(f"✓ Normalized {len(feature_cols)} features")
print(f"  Method: StandardScaler")
# Out:
# ✓ Normalized 16 features
#   Method: StandardScaler

# %%
def create_sequences(df, window_size, stride, feature_cols, is_train=True):
    """Create sequences using sliding window"""
    X_list = []
    y_list = []
    engine_ids_list = []

    for engine_id, engine_data in df.groupby('engine'):
        engine_data = engine_data.sort_values('cycle').reset_index(drop=True)
        features = engine_data[feature_cols].values

        if len(engine_data) < window_size:
            continue

        if is_train:
            rul = engine_data['RUL'].values
            for i in range(0, len(engine_data) - window_size + 1, stride):
                X_list.append(features[i:i + window_size])
                y_list.append(rul[i + window_size - 1])
                engine_ids_list.append(engine_id)
        else:
            for i in range(0, len(engine_data) - window_size + 1, stride):
                X_list.append(features[i:i + window_size])
                engine_ids_list.append(engine_id)

    X = np.array(X_list)
    engine_ids = np.array(engine_ids_list)

    if is_train:
        y = np.array(y_list)
        return X, y, engine_ids
    else:
        return X, engine_ids

# Create sequences
X_train, y_train, train_engine_ids = create_sequences(
    df_train_norm, CONFIG['WINDOW_SIZE'], CONFIG['STRIDE'],
    feature_cols, is_train=True
)

X_test, test_engine_ids = create_sequences(
    df_test_norm, CONFIG['WINDOW_SIZE'], CONFIG['STRIDE'],
    feature_cols, is_train=False
)

print(f"✓ Training sequences: {X_train.shape}")
print(f"  - Samples: {X_train.shape[0]}")
print(f"  - Timesteps: {X_train.shape[1]}")
print(f"  - Features: {X_train.shape[2]}")
print(f"✓ Test sequences: {X_test.shape}")
# Out:
# ✓ Training sequences: (17731, 30, 16)
#   - Samples: 17731
#   - Timesteps: 30
#   - Features: 16
# ✓ Test sequences: (10196, 30, 16)

# %%
class GatingLayer(layers.Layer):
    """
    Custom gating layer to learn branch importance dynamically
    This is the NOVEL component!
    """
    def __init__(self, num_branches, **kwargs):
        super(GatingLayer, self).__init__(**kwargs)
        self.num_branches = num_branches

    def build(self, input_shape):
        # Gating weights (one per branch)
        # input_shape will be a list of shapes, e.g., [(None, timesteps, features), ...]
        # We need the last dimension (features) from one of these shapes
        self.gate_weights = self.add_weight(
            shape=(input_shape[0][-1], self.num_branches),
            initializer='glorot_uniform',
            trainable=True,
            name='gate_weights'
        )
        self.gate_bias = self.add_weight(
            shape=(self.num_branches,),
            initializer='zeros',
            trainable=True,
            name='gate_bias'
        )

    def call(self, inputs):
        # inputs: list of [branch_1, branch_2, branch_3]
        # Each branch shape: (batch, timesteps, features)

        # Compute gating scores from input statistics
        input_stats = tf.reduce_mean(inputs[0], axis=1)  # (batch, features)
        gate_scores = tf.nn.softmax(
            tf.matmul(input_stats, self.gate_weights) + self.gate_bias,
            axis=-1
        )  # (batch, num_branches)

        # Apply gates to each branch
        gate_scores = tf.expand_dims(gate_scores, 1)  # (batch, 1, num_branches)
        gate_scores = tf.expand_dims(gate_scores, -1)  # (batch, 1, num_branches, 1)

        # Stack branches
        stacked = tf.stack(inputs, axis=2)  # (batch, timesteps, num_branches, features)

        # Apply gating
        gated = stacked * gate_scores  # Broadcasting

        # Sum across branches
        fused = tf.reduce_sum(gated, axis=2)  # (batch, timesteps, features)

        return fused

    def get_config(self):
        config = super().get_config()
        config.update({"num_branches": self.num_branches})
        return config

print("✓ Gating layer defined")
# Out:
# ✓ Gating layer defined

# %%
def build_gated_ensemble_bilstm(input_shape, config):
    """
    NOVEL Gated Ensemble BiLSTM Architecture

    Layer 1: Parallel branches (LSTM, GRU, CNN)
    Layer 2: Learned gating mechanism
    Layer 3-4: BiLSTM layers
    Layer 5: Dense output
    """

    inputs = layers.Input(shape=input_shape, name='input')

    # ========================================================================
    # LAYER 1: PARALLEL BRANCHES (ENSEMBLE)
    # ========================================================================

    # Branch 1: LSTM (traditional temporal modeling)
    branch_lstm = layers.LSTM(
        64,
        return_sequences=True,
        kernel_regularizer=regularizers.l2(config['L2_REG']),
        recurrent_regularizer=regularizers.l2(config['L2_REG']),
        name='lstm_branch'
    )(inputs)
    branch_lstm = layers.LayerNormalization(name='ln_lstm')(branch_lstm)
    branch_lstm = layers.Dropout(config['DROPOUT_RATE'], name='dropout_lstm')(branch_lstm)

    # Branch 2: GRU (simpler gating, different dynamics)
    branch_gru = layers.GRU(
        64,
        return_sequences=True,
        kernel_regularizer=regularizers.l2(config['L2_REG']),
        recurrent_regularizer=regularizers.l2(config['L2_REG']),
        name='gru_branch'
    )(inputs)
    branch_gru = layers.LayerNormalization(name='ln_gru')(branch_gru)
    branch_gru = layers.Dropout(config['DROPOUT_RATE'], name='dropout_gru')(branch_gru)

    # Branch 3: 1D CNN (local pattern detection)
    branch_cnn = layers.Conv1D(
        filters=64,
        kernel_size=5,
        padding='same',
        activation='relu',
        kernel_regularizer=regularizers.l2(config['L2_REG']),
        name='cnn_branch'
    )(inputs)
    branch_cnn = layers.Conv1D(
        filters=64,
        kernel_size=3,
        padding='same',
        activation='relu',
        kernel_regularizer=regularizers.l2(config['L2_REG']),
        name='cnn_branch_2'
    )(branch_cnn)
    branch_cnn = layers.LayerNormalization(name='ln_cnn')(branch_cnn)
    branch_cnn = layers.Dropout(config['DROPOUT_RATE'], name='dropout_cnn')(branch_cnn)

    # ========================================================================
    # LAYER 2: GATED FUSION (NOVEL!)
    # ========================================================================

    # Learnable gating mechanism
    gating = GatingLayer(num_branches=3, name='gating_layer')
    fused_features = gating([branch_lstm, branch_gru, branch_cnn])

    # ========================================================================
    # LAYER 3: BiLSTM (Process Fused Features)
    # ========================================================================

    x = layers.Bidirectional(
        layers.LSTM(
            config['LSTM_UNITS'][0],
            return_sequences=True,
            kernel_regularizer=regularizers.l2(config['L2_REG']),
            recurrent_regularizer=regularizers.l2(config['L2_REG']),
            name='bilstm_1'
        ),
        name='bidirectional_1'
    )(fused_features)
    x = layers.LayerNormalization(name='ln_1')(x)
    x = layers.Dropout(config['DROPOUT_RATE'], name='dropout_1')(x)

    # ========================================================================
    # LAYER 4: Second BiLSTM
    # ========================================================================

    x = layers.Bidirectional(
        layers.LSTM(
            config['LSTM_UNITS'][1],
            return_sequences=False,
            kernel_regularizer=regularizers.l2(config['L2_REG']),
            recurrent_regularizer=regularizers.l2(config['L2_REG']),
            name='bilstm_2'
        ),
        name='bidirectional_2'
    )(x)
    x = layers.LayerNormalization(name='ln_2')(x)
    x = layers.Dropout(config['DROPOUT_RATE'], name='dropout_2')(x)

    # ========================================================================
    # LAYER 5: Dense Layers
    # ========================================================================

    x = layers.Dense(
        config['DENSE_UNITS'],
        activation='relu',
        kernel_regularizer=regularizers.l2(config['L2_REG']),
        name='dense_1'
    )(x)
    x = layers.Dropout(config['DROPOUT_RATE'], name='dropout_3')(x)

    # Output
    outputs = layers.Dense(1, activation='linear', name='rul_output')(x)

    # Create model
    model = models.Model(inputs=inputs, outputs=outputs, name='Gated_Ensemble_BiLSTM')

    # Compile
    model.compile(
        optimizer=Adam(learning_rate=config['LEARNING_RATE']),
        loss=tf.keras.losses.Huber(delta=1.0),
        metrics=['mae', 'mse']
    )

    return model

# Build model
input_shape = (X_train.shape[1], X_train.shape[2])
model = build_gated_ensemble_bilstm(input_shape, CONFIG)

print("\nModel Architecture:")
model.summary()

print("\n✓ NOVEL Architecture Components:")
print("  1. Parallel Branches: LSTM + GRU + CNN")
print("  2. Gating Layer: Learns branch importance dynamically")
print("  3. BiLSTM Integration: Processes fused features")
print("  4. Total Parameters: ~", model.count_params())
# Out:
# Model Architecture:
# Model: "Gated_Ensemble_BiLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 30, 16)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cnn_branch (Conv1D) │ (None, 30, 64)    │      5,184 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_branch (LSTM)  │ (None, 30, 64)    │     20,736 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_branch (GRU)    │ (None, 30, 64)    │     15,744 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cnn_branch_2        │ (None, 30, 64)    │     12,352 │ cnn_branch[0][0]  │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_lstm             │ (None, 30, 64)    │        128 │ lstm_branch[0][0] │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_gru              │ (None, 30, 64)    │        128 │ gru_branch[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_cnn              │ (None, 30, 64)    │        128 │ cnn_branch_2[0][… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_lstm        │ (None, 30, 64)    │          0 │ ln_lstm[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_gru         │ (None, 30, 64)    │          0 │ ln_gru[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_cnn         │ (None, 30, 64)    │          0 │ ln_cnn[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gating_layer        │ (None, 30, 64)    │        195 │ dropout_lstm[0][… │
# │ (GatingLayer)       │                   │            │ dropout_gru[0][0… │
# │                     │                   │            │ dropout_cnn[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 30, 256)   │    197,632 │ gating_layer[0][… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_1                │ (None, 30, 256)   │        512 │ bidirectional_1[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 30, 256)   │          0 │ ln_1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 128)       │    164,352 │ dropout_1[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_2                │ (None, 128)       │        256 │ bidirectional_2[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ ln_2[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 50)        │      6,450 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 50)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rul_output (Dense)  │ (None, 1)         │         51 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 423,848 (1.62 MB)
#  Trainable params: 423,848 (1.62 MB)
#  Non-trainable params: 0 (0.00 B)
# ✓ NOVEL Architecture Components:
#   1. Parallel Branches: LSTM + GRU + CNN
#   2. Gating Layer: Learns branch importance dynamically
#   3. BiLSTM Integration: Processes fused features
#   4. Total Parameters: ~ 423848

# %%
gkf = GroupKFold(n_splits=CONFIG['N_SPLITS'])

fold_models = []
fold_histories = []
fold_val_scores = []

print(f"Training with {CONFIG['N_SPLITS']}-Fold Cross-Validation\n")

for fold, (train_idx, val_idx) in enumerate(gkf.split(X_train, y_train, train_engine_ids), 1):
    print(f"\n{'='*70}")
    print(f"FOLD {fold}/{CONFIG['N_SPLITS']}")
    print(f"{'='*70}")

    X_tr, X_val = X_train[train_idx], X_train[val_idx]
    y_tr, y_val = y_train[train_idx], y_train[val_idx]

    print(f"Train: {len(X_tr)} samples, Val: {len(X_val)} samples")

    # Build fresh model
    model = build_gated_ensemble_bilstm(input_shape, CONFIG)

    # Callbacks
    early_stop = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=CONFIG['PATIENCE'],
        restore_best_weights=True,
        verbose=0
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-6,
        verbose=0
    )

    # Train
    history = model.fit(
        X_tr, y_tr,
        validation_data=(X_val, y_val),
        epochs=CONFIG['EPOCHS'],
        batch_size=CONFIG['BATCH_SIZE'],
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    # Evaluate
    val_loss, val_mae, val_mse = model.evaluate(X_val, y_val, verbose=0)
    val_rmse = np.sqrt(val_mse)
    y_val_pred = model.predict(X_val, verbose=0).flatten()
    val_r2 = r2_score(y_val, y_val_pred)

    print(f"\n✓ Fold {fold} Results:")
    print(f"  Val MAE:  {val_mae:.4f}")
    print(f"  Val RMSE: {val_rmse:.4f}")
    print(f"  Val R²:   {val_r2:.4f}")
    print(f"  Epochs:   {len(history.history['loss'])}")

    fold_models.append(model)
    fold_histories.append(history)
    fold_val_scores.append({
        'mae': val_mae,
        'rmse': val_rmse,
        'r2': val_r2
    })
# Out:
# Training with 5-Fold Cross-Validation
#
#
# ======================================================================
# FOLD 1/5
# ======================================================================
# Train: 14191 samples, Val: 3540 samples
# Epoch 1/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - loss: 49.8897 - mae: 49.0021 - mse: 3835.1663 - val_loss: 15.6553 - val_mae: 14.8497 - val_mse: 372.9348 - learning_rate: 0.0010
# Epoch 2/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 17.6756 - mae: 16.8767 - mse: 479.7072 - val_loss: 14.6993 - val_mae: 13.9252 - val_mse: 327.5324 - learning_rate: 0.0010
# Epoch 3/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 16.0895 - mae: 15.3162 - mse: 409.7096 - val_loss: 15.0886 - val_mae: 14.3222 - val_mse: 341.2023 - learning_rate: 0.0010
# Epoch 4/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 15.0466 - mae: 14.2738 - mse: 356.7557 - val_loss: 13.8252 - val_mae: 13.0552 - val_mse: 307.7166 - learning_rate: 0.0010
# Epoch 5/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 14.5875 - mae: 13.8149 - mse: 331.1350 - val_loss: 14.1355 - val_mae: 13.3717 - val_mse: 383.7282 - learning_rate: 0.0010
# Epoch 6/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 13.7395 - mae: 12.9763 - mse: 298.4496 - val_loss: 14.9429 - val_mae: 14.1764 - val_mse: 358.5742 - learning_rate: 0.0010
# Epoch 7/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 13.3190 - mae: 12.5477 - mse: 281.0359 - val_loss: 14.9504 - val_mae: 14.1827 - val_mse: 371.7995 - learning_rate: 0.0010
# Epoch 8/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 12.9407 - mae: 12.1727 - mse: 262.1139 - val_loss: 15.8245 - val_mae: 15.0601 - val_mse: 395.7389 - learning_rate: 0.0010
# Epoch 9/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 12.7412 - mae: 11.9717 - mse: 256.7015 - val_loss: 14.7050 - val_mae: 13.9479 - val_mse: 368.9344 - learning_rate: 0.0010
# Epoch 10/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 12.0227 - mae: 11.2633 - mse: 228.6340 - val_loss: 13.8250 - val_mae: 13.0728 - val_mse: 353.1989 - learning_rate: 0.0010
# Epoch 11/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - loss: 11.9141 - mae: 11.1615 - mse: 226.0438 - val_loss: 13.9353 - val_mae: 13.1749 - val_mse: 355.9570 - learning_rate: 0.0010
# Epoch 12/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 11.5361 - mae: 10.7914 - mse: 208.6487 - val_loss: 14.5861 - val_mae: 13.8583 - val_mse: 359.6897 - learning_rate: 0.0010
# Epoch 13/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 11.3482 - mae: 10.6184 - mse: 203.8890 - val_loss: 14.3257 - val_mae: 13.5965 - val_mse: 379.0261 - learning_rate: 0.0010
# Epoch 14/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 11.5679 - mae: 10.8401 - mse: 212.9185 - val_loss: 14.7099 - val_mae: 13.9917 - val_mse: 351.4731 - learning_rate: 0.0010
# Epoch 15/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 11.0640 - mae: 10.3407 - mse: 196.2839 - val_loss: 14.7013 - val_mae: 13.9896 - val_mse: 387.1732 - learning_rate: 0.0010
# Epoch 16/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 10.9488 - mae: 10.2354 - mse: 189.5144 - val_loss: 15.2918 - val_mae: 14.5954 - val_mse: 400.9020 - learning_rate: 0.0010
# Epoch 17/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.8112 - mae: 10.1117 - mse: 185.6328 - val_loss: 14.5767 - val_mae: 13.8940 - val_mse: 386.1052 - learning_rate: 0.0010
# Epoch 18/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 10.5455 - mae: 9.8595 - mse: 179.5024 - val_loss: 16.1333 - val_mae: 15.4586 - val_mse: 417.8671 - learning_rate: 0.0010
# Epoch 19/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 10.3121 - mae: 9.6449 - mse: 172.7528 - val_loss: 15.2907 - val_mae: 14.6493 - val_mse: 397.0141 - learning_rate: 5.0000e-04
# Epoch 20/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 10.1582 - mae: 9.5137 - mse: 166.4195 - val_loss: 14.8886 - val_mae: 14.2720 - val_mse: 385.4696 - learning_rate: 5.0000e-04
# Epoch 21/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 10.1090 - mae: 9.4895 - mse: 167.8273 - val_loss: 15.7977 - val_mae: 15.2028 - val_mse: 397.8123 - learning_rate: 5.0000e-04
# Epoch 22/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 10.0638 - mae: 9.4662 - mse: 166.8190 - val_loss: 15.2311 - val_mae: 14.6563 - val_mse: 415.6610 - learning_rate: 5.0000e-04
# Epoch 23/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 10.1592 - mae: 9.5837 - mse: 172.6016 - val_loss: 15.1395 - val_mae: 14.5876 - val_mse: 400.6489 - learning_rate: 5.0000e-04
# Epoch 24/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.8851 - mae: 9.3291 - mse: 163.4531 - val_loss: 15.2362 - val_mae: 14.7041 - val_mse: 412.3360 - learning_rate: 5.0000e-04
# Epoch 25/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 9.7769 - mae: 9.2372 - mse: 161.3498 - val_loss: 15.3211 - val_mae: 14.8030 - val_mse: 433.9490 - learning_rate: 5.0000e-04
# Epoch 26/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.8513 - mae: 9.3290 - mse: 165.8338 - val_loss: 14.5141 - val_mae: 14.0131 - val_mse: 384.0849 - learning_rate: 5.0000e-04
# Epoch 27/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.6573 - mae: 9.1522 - mse: 159.2537 - val_loss: 14.4811 - val_mae: 13.9926 - val_mse: 378.5786 - learning_rate: 2.5000e-04
# Epoch 28/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.6915 - mae: 9.1971 - mse: 162.3762 - val_loss: 14.8279 - val_mae: 14.3546 - val_mse: 402.1685 - learning_rate: 2.5000e-04
# Epoch 29/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.5089 - mae: 9.0290 - mse: 157.0027 - val_loss: 14.4228 - val_mae: 13.9632 - val_mse: 376.3067 - learning_rate: 2.5000e-04
# Epoch 30/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.5064 - mae: 9.0395 - mse: 155.9227 - val_loss: 14.9215 - val_mae: 14.4729 - val_mse: 406.8506 - learning_rate: 2.5000e-04
# Epoch 31/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 9.5202 - mae: 9.0664 - mse: 152.9235 - val_loss: 14.5531 - val_mae: 14.1160 - val_mse: 396.1606 - learning_rate: 2.5000e-04
# Epoch 32/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.4130 - mae: 8.9687 - mse: 155.1134 - val_loss: 15.1915 - val_mae: 14.7671 - val_mse: 400.6557 - learning_rate: 2.5000e-04
# Epoch 33/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 9.3811 - mae: 8.9512 - mse: 152.9350 - val_loss: 14.4983 - val_mae: 14.0850 - val_mse: 389.8370 - learning_rate: 2.5000e-04
# Epoch 34/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 9.4640 - mae: 9.0421 - mse: 154.8876 - val_loss: 15.0890 - val_mae: 14.6880 - val_mse: 407.5394 - learning_rate: 2.5000e-04
# Epoch 35/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.3951 - mae: 8.9832 - mse: 153.4634 - val_loss: 15.0839 - val_mae: 14.6873 - val_mse: 399.7826 - learning_rate: 1.2500e-04
#
# ✓ Fold 1 Results:
#   Val MAE:  13.0728
#   Val RMSE: 18.7936
#   Val R²:   0.7982
#   Epochs:   35
#
# ======================================================================
# FOLD 2/5
# ======================================================================
# Train: 14178 samples, Val: 3553 samples
# Epoch 1/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 50.3420 - mae: 49.4801 - mse: 3889.5820 - val_loss: 16.3599 - val_mae: 15.6665 - val_mse: 409.4030 - learning_rate: 0.0010
# Epoch 2/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 18.0469 - mae: 17.3779 - mse: 517.8624 - val_loss: 15.2330 - val_mae: 14.6221 - val_mse: 355.0999 - learning_rate: 0.0010
# Epoch 3/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 16.2900 - mae: 15.6867 - mse: 434.1649 - val_loss: 12.9712 - val_mae: 12.3933 - val_mse: 317.5201 - learning_rate: 0.0010
# Epoch 4/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 15.3728 - mae: 14.8053 - mse: 389.2820 - val_loss: 13.2237 - val_mae: 12.6778 - val_mse: 314.4176 - learning_rate: 0.0010
# Epoch 5/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 14.8230 - mae: 14.2846 - mse: 370.5470 - val_loss: 14.0018 - val_mae: 13.4626 - val_mse: 325.4443 - learning_rate: 0.0010
# Epoch 6/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 14.1290 - mae: 13.5944 - mse: 332.3761 - val_loss: 13.0794 - val_mae: 12.5571 - val_mse: 283.8894 - learning_rate: 0.0010
# Epoch 7/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 13.5920 - mae: 13.0782 - mse: 304.6320 - val_loss: 13.3754 - val_mae: 12.8795 - val_mse: 314.7692 - learning_rate: 0.0010
# Epoch 8/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 13.1263 - mae: 12.6351 - mse: 286.0568 - val_loss: 12.2521 - val_mae: 11.7760 - val_mse: 273.2241 - learning_rate: 0.0010
# Epoch 9/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 12.7395 - mae: 12.2634 - mse: 268.1019 - val_loss: 11.9975 - val_mae: 11.5245 - val_mse: 284.6934 - learning_rate: 0.0010
# Epoch 10/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 12.4168 - mae: 11.9498 - mse: 254.2280 - val_loss: 12.5841 - val_mae: 12.1097 - val_mse: 332.9434 - learning_rate: 0.0010
# Epoch 11/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 11.9454 - mae: 11.4937 - mse: 239.8853 - val_loss: 13.2941 - val_mae: 12.8594 - val_mse: 327.7357 - learning_rate: 0.0010
# Epoch 12/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 11.7664 - mae: 11.3303 - mse: 230.5449 - val_loss: 12.5338 - val_mae: 12.1069 - val_mse: 298.4208 - learning_rate: 0.0010
# Epoch 13/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 11.4259 - mae: 10.9997 - mse: 219.6590 - val_loss: 13.6341 - val_mae: 13.2160 - val_mse: 353.8448 - learning_rate: 0.0010
# Epoch 14/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 11.2321 - mae: 10.8120 - mse: 212.5285 - val_loss: 12.5262 - val_mae: 12.1055 - val_mse: 320.9043 - learning_rate: 0.0010
# Epoch 15/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 11.0786 - mae: 10.6680 - mse: 206.1715 - val_loss: 11.6414 - val_mae: 11.2079 - val_mse: 305.6624 - learning_rate: 0.0010
# Epoch 16/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 10.7055 - mae: 10.3001 - mse: 196.1533 - val_loss: 12.9447 - val_mae: 12.5509 - val_mse: 330.4894 - learning_rate: 0.0010
# Epoch 17/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.6293 - mae: 10.2339 - mse: 191.2542 - val_loss: 14.4369 - val_mae: 14.0512 - val_mse: 379.6489 - learning_rate: 0.0010
# Epoch 18/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 10.5689 - mae: 10.1855 - mse: 190.9060 - val_loss: 14.0022 - val_mae: 13.6266 - val_mse: 352.7451 - learning_rate: 0.0010
# Epoch 19/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 10.4681 - mae: 10.0892 - mse: 188.4379 - val_loss: 13.8307 - val_mae: 13.4573 - val_mse: 367.5963 - learning_rate: 0.0010
# Epoch 20/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.2585 - mae: 9.8829 - mse: 181.3279 - val_loss: 12.6974 - val_mae: 12.3270 - val_mse: 318.0691 - learning_rate: 0.0010
# Epoch 21/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 10.2983 - mae: 9.9272 - mse: 186.3402 - val_loss: 13.3887 - val_mae: 13.0223 - val_mse: 354.3870 - learning_rate: 0.0010
# Epoch 22/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 10.3948 - mae: 10.0220 - mse: 185.3779 - val_loss: 12.9984 - val_mae: 12.6236 - val_mse: 323.3830 - learning_rate: 0.0010
# Epoch 23/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.1820 - mae: 9.8022 - mse: 175.2725 - val_loss: 12.4388 - val_mae: 12.0717 - val_mse: 312.2726 - learning_rate: 0.0010
# Epoch 24/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.6039 - mae: 9.2351 - mse: 159.7962 - val_loss: 13.1550 - val_mae: 12.8095 - val_mse: 339.3845 - learning_rate: 5.0000e-04
# Epoch 25/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 9.6900 - mae: 9.3418 - mse: 163.9817 - val_loss: 12.7959 - val_mae: 12.4683 - val_mse: 343.4268 - learning_rate: 5.0000e-04
# Epoch 26/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.5708 - mae: 9.2416 - mse: 161.9579 - val_loss: 13.3327 - val_mae: 13.0217 - val_mse: 368.4214 - learning_rate: 5.0000e-04
# Epoch 27/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.5823 - mae: 9.2698 - mse: 161.7589 - val_loss: 13.2532 - val_mae: 12.9576 - val_mse: 347.6066 - learning_rate: 5.0000e-04
# Epoch 28/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.3489 - mae: 9.0510 - mse: 153.6483 - val_loss: 13.5417 - val_mae: 13.2597 - val_mse: 375.8574 - learning_rate: 5.0000e-04
# Epoch 29/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.5623 - mae: 9.2765 - mse: 163.2768 - val_loss: 13.4573 - val_mae: 13.1873 - val_mse: 380.1075 - learning_rate: 5.0000e-04
# Epoch 30/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 9.2457 - mae: 8.9710 - mse: 151.6624 - val_loss: 13.3456 - val_mae: 13.0856 - val_mse: 361.3172 - learning_rate: 5.0000e-04
# Epoch 31/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.3882 - mae: 9.1223 - mse: 158.8138 - val_loss: 13.3039 - val_mae: 13.0512 - val_mse: 360.4107 - learning_rate: 5.0000e-04
# Epoch 32/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.2204 - mae: 8.9634 - mse: 150.7942 - val_loss: 13.4388 - val_mae: 13.1948 - val_mse: 372.1383 - learning_rate: 2.5000e-04
# Epoch 33/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.1501 - mae: 8.9013 - mse: 149.0640 - val_loss: 12.8985 - val_mae: 12.6619 - val_mse: 370.4056 - learning_rate: 2.5000e-04
# Epoch 34/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.1108 - mae: 8.8716 - mse: 151.4991 - val_loss: 12.8449 - val_mae: 12.6194 - val_mse: 339.5928 - learning_rate: 2.5000e-04
# Epoch 35/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.0173 - mae: 8.7870 - mse: 147.6876 - val_loss: 13.6184 - val_mae: 13.4002 - val_mse: 372.0538 - learning_rate: 2.5000e-04
# Epoch 36/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 8.8835 - mae: 8.6590 - mse: 144.4614 - val_loss: 13.2141 - val_mae: 12.9980 - val_mse: 384.2391 - learning_rate: 2.5000e-04
# Epoch 37/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 8.9723 - mae: 8.7567 - mse: 146.8680 - val_loss: 13.6575 - val_mae: 13.4551 - val_mse: 371.8910 - learning_rate: 2.5000e-04
# Epoch 38/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 8.9105 - mae: 8.7002 - mse: 145.7260 - val_loss: 13.5792 - val_mae: 13.3834 - val_mse: 373.9228 - learning_rate: 2.5000e-04
# Epoch 39/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 8.9126 - mae: 8.7115 - mse: 144.1981 - val_loss: 13.2268 - val_mae: 13.0384 - val_mse: 366.7740 - learning_rate: 2.5000e-04
# Epoch 40/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 8.9340 - mae: 8.7383 - mse: 146.4910 - val_loss: 12.9305 - val_mae: 12.7441 - val_mse: 359.5682 - learning_rate: 1.2500e-04
#
# ✓ Fold 2 Results:
#   Val MAE:  11.2079
#   Val RMSE: 17.4832
#   Val R²:   0.8248
#   Epochs:   40
#
# ======================================================================
# FOLD 3/5
# ======================================================================
# Train: 14185 samples, Val: 3546 samples
# Epoch 1/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - loss: 48.9643 - mae: 48.0802 - mse: 3727.7668 - val_loss: 12.7996 - val_mae: 12.0381 - val_mse: 258.6772 - learning_rate: 0.0010
# Epoch 2/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 17.4630 - mae: 16.7217 - mse: 472.5388 - val_loss: 12.1258 - val_mae: 11.4287 - val_mse: 250.8175 - learning_rate: 0.0010
# Epoch 3/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 15.5608 - mae: 14.8766 - mse: 379.3669 - val_loss: 11.5900 - val_mae: 10.9399 - val_mse: 232.5386 - learning_rate: 0.0010
# Epoch 4/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 14.4191 - mae: 13.7755 - mse: 328.8232 - val_loss: 13.0545 - val_mae: 12.4303 - val_mse: 282.2188 - learning_rate: 0.0010
# Epoch 5/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 13.7112 - mae: 13.0934 - mse: 296.4551 - val_loss: 11.7072 - val_mae: 11.1101 - val_mse: 234.1503 - learning_rate: 0.0010
# Epoch 6/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 13.1320 - mae: 12.5356 - mse: 275.3032 - val_loss: 10.5611 - val_mae: 9.9741 - val_mse: 228.7067 - learning_rate: 0.0010
# Epoch 7/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 12.8037 - mae: 12.2192 - mse: 262.5744 - val_loss: 11.4180 - val_mae: 10.8480 - val_mse: 213.5789 - learning_rate: 0.0010
# Epoch 8/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 12.4909 - mae: 11.9265 - mse: 250.4948 - val_loss: 11.8348 - val_mae: 11.2871 - val_mse: 257.4766 - learning_rate: 0.0010
# Epoch 9/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 12.2918 - mae: 11.7465 - mse: 241.4909 - val_loss: 12.7621 - val_mae: 12.2235 - val_mse: 290.1902 - learning_rate: 0.0010
# Epoch 10/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 12.0220 - mae: 11.4819 - mse: 236.2665 - val_loss: 12.4377 - val_mae: 11.9062 - val_mse: 252.8305 - learning_rate: 0.0010
# Epoch 11/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 11.6812 - mae: 11.1465 - mse: 222.6289 - val_loss: 12.2886 - val_mae: 11.7640 - val_mse: 291.2485 - learning_rate: 0.0010
# Epoch 12/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 11.6887 - mae: 11.1636 - mse: 222.4730 - val_loss: 10.9265 - val_mae: 10.4139 - val_mse: 218.9008 - learning_rate: 0.0010
# Epoch 13/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 11.3860 - mae: 10.8700 - mse: 215.9419 - val_loss: 11.6240 - val_mae: 11.1202 - val_mse: 277.9846 - learning_rate: 0.0010
# Epoch 14/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 11.3171 - mae: 10.8143 - mse: 212.2629 - val_loss: 11.4545 - val_mae: 10.9600 - val_mse: 225.6120 - learning_rate: 0.0010
# Epoch 15/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.9094 - mae: 10.4155 - mse: 194.8668 - val_loss: 11.8811 - val_mae: 11.4063 - val_mse: 249.0342 - learning_rate: 5.0000e-04
# Epoch 16/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.6527 - mae: 10.1773 - mse: 191.5165 - val_loss: 11.0263 - val_mae: 10.5695 - val_mse: 225.0535 - learning_rate: 5.0000e-04
# Epoch 17/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.4555 - mae: 10.0006 - mse: 183.0170 - val_loss: 11.2371 - val_mae: 10.8020 - val_mse: 227.9565 - learning_rate: 5.0000e-04
# Epoch 18/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 10.2957 - mae: 9.8581 - mse: 180.7028 - val_loss: 10.9395 - val_mae: 10.5231 - val_mse: 225.4810 - learning_rate: 5.0000e-04
# Epoch 19/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.4674 - mae: 10.0479 - mse: 187.7983 - val_loss: 11.9725 - val_mae: 11.5678 - val_mse: 265.1436 - learning_rate: 5.0000e-04
# Epoch 20/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 10.2778 - mae: 9.8725 - mse: 180.9284 - val_loss: 12.2559 - val_mae: 11.8627 - val_mse: 273.7197 - learning_rate: 5.0000e-04
# Epoch 21/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.2723 - mae: 9.8795 - mse: 181.3746 - val_loss: 10.8556 - val_mae: 10.4752 - val_mse: 224.2710 - learning_rate: 5.0000e-04
# Epoch 22/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 10.3451 - mae: 9.9625 - mse: 186.2511 - val_loss: 10.9577 - val_mae: 10.5910 - val_mse: 225.3269 - learning_rate: 5.0000e-04
# Epoch 23/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 10.0803 - mae: 9.7090 - mse: 177.5616 - val_loss: 11.5031 - val_mae: 11.1438 - val_mse: 250.8540 - learning_rate: 2.5000e-04
# Epoch 24/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.7711 - mae: 9.4092 - mse: 168.3522 - val_loss: 11.4705 - val_mae: 11.1216 - val_mse: 245.6974 - learning_rate: 2.5000e-04
# Epoch 25/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.9052 - mae: 9.5536 - mse: 171.4365 - val_loss: 11.6197 - val_mae: 11.2820 - val_mse: 255.9582 - learning_rate: 2.5000e-04
# Epoch 26/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.7768 - mae: 9.4344 - mse: 167.2141 - val_loss: 11.2462 - val_mae: 10.9155 - val_mse: 236.2842 - learning_rate: 2.5000e-04
# Epoch 27/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.6043 - mae: 9.2712 - mse: 163.1888 - val_loss: 12.1465 - val_mae: 11.8287 - val_mse: 267.4530 - learning_rate: 2.5000e-04
# Epoch 28/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.8607 - mae: 9.5360 - mse: 171.8739 - val_loss: 10.3676 - val_mae: 10.0583 - val_mse: 221.6893 - learning_rate: 2.5000e-04
# Epoch 29/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.9096 - mae: 9.5933 - mse: 172.9628 - val_loss: 11.7265 - val_mae: 11.4217 - val_mse: 264.4350 - learning_rate: 2.5000e-04
# Epoch 30/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 9.6470 - mae: 9.3395 - mse: 166.4092 - val_loss: 12.0368 - val_mae: 11.7408 - val_mse: 278.3528 - learning_rate: 2.5000e-04
# Epoch 31/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.5714 - mae: 9.2704 - mse: 162.6811 - val_loss: 11.8057 - val_mae: 11.5199 - val_mse: 284.7968 - learning_rate: 2.5000e-04
# Epoch 32/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.5075 - mae: 9.2138 - mse: 160.2473 - val_loss: 11.1990 - val_mae: 10.9169 - val_mse: 237.6457 - learning_rate: 2.5000e-04
# Epoch 33/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.4804 - mae: 9.1945 - mse: 160.1172 - val_loss: 11.2305 - val_mae: 10.9581 - val_mse: 241.2383 - learning_rate: 2.5000e-04
# Epoch 34/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.5955 - mae: 9.3165 - mse: 163.0482 - val_loss: 10.7990 - val_mae: 10.5303 - val_mse: 229.5800 - learning_rate: 2.5000e-04
# Epoch 35/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.6080 - mae: 9.3349 - mse: 165.1376 - val_loss: 12.0211 - val_mae: 11.7590 - val_mse: 282.3380 - learning_rate: 2.5000e-04
# Epoch 36/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.5706 - mae: 9.3072 - mse: 163.1122 - val_loss: 11.8750 - val_mae: 11.6204 - val_mse: 275.7386 - learning_rate: 2.5000e-04
# Epoch 37/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 9.4256 - mae: 9.1652 - mse: 159.5839 - val_loss: 11.9698 - val_mae: 11.7222 - val_mse: 273.6027 - learning_rate: 1.2500e-04
# Epoch 38/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 9.5942 - mae: 9.3393 - mse: 165.7278 - val_loss: 11.8340 - val_mae: 11.5908 - val_mse: 263.1609 - learning_rate: 1.2500e-04
# Epoch 39/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.4796 - mae: 9.2304 - mse: 162.5374 - val_loss: 11.6854 - val_mae: 11.4462 - val_mse: 257.7790 - learning_rate: 1.2500e-04
# Epoch 40/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 9.3938 - mae: 9.1468 - mse: 159.9564 - val_loss: 11.3864 - val_mae: 11.1482 - val_mse: 256.0611 - learning_rate: 1.2500e-04
# Epoch 41/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.2816 - mae: 9.0399 - mse: 155.9699 - val_loss: 11.3186 - val_mae: 11.0868 - val_mse: 248.3996 - learning_rate: 1.2500e-04
# Epoch 42/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.3709 - mae: 9.1324 - mse: 157.7809 - val_loss: 11.7340 - val_mae: 11.5044 - val_mse: 273.5842 - learning_rate: 1.2500e-04
# Epoch 43/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 8.9953 - mae: 8.7614 - mse: 144.4203 - val_loss: 11.8759 - val_mae: 11.6528 - val_mse: 275.1884 - learning_rate: 1.2500e-04
# Epoch 44/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.2575 - mae: 9.0276 - mse: 157.5893 - val_loss: 11.2479 - val_mae: 11.0260 - val_mse: 261.6456 - learning_rate: 1.2500e-04
# Epoch 45/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.2273 - mae: 9.0020 - mse: 154.9576 - val_loss: 11.9853 - val_mae: 11.7697 - val_mse: 277.0502 - learning_rate: 6.2500e-05
# Epoch 46/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.1439 - mae: 8.9199 - mse: 152.2843 - val_loss: 11.8370 - val_mae: 11.6218 - val_mse: 273.3165 - learning_rate: 6.2500e-05
# Epoch 47/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.2712 - mae: 9.0490 - mse: 156.4311 - val_loss: 11.7367 - val_mae: 11.5250 - val_mse: 272.4478 - learning_rate: 6.2500e-05
# Epoch 48/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.0973 - mae: 8.8779 - mse: 151.7594 - val_loss: 11.6250 - val_mae: 11.4147 - val_mse: 271.7101 - learning_rate: 6.2500e-05
# Epoch 49/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 9.2777 - mae: 9.0608 - mse: 158.2419 - val_loss: 11.9124 - val_mae: 11.7044 - val_mse: 279.2094 - learning_rate: 6.2500e-05
# Epoch 50/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.1994 - mae: 8.9849 - mse: 154.7354 - val_loss: 11.9431 - val_mae: 11.7379 - val_mse: 276.5802 - learning_rate: 6.2500e-05
# Epoch 51/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.2779 - mae: 9.0650 - mse: 155.5064 - val_loss: 11.8749 - val_mae: 11.6720 - val_mse: 278.7164 - learning_rate: 6.2500e-05
# Epoch 52/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 9.1657 - mae: 8.9565 - mse: 152.5836 - val_loss: 11.8790 - val_mae: 11.6786 - val_mse: 274.5294 - learning_rate: 6.2500e-05
# Epoch 53/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 9.2126 - mae: 9.0042 - mse: 155.7995 - val_loss: 11.4980 - val_mae: 11.2971 - val_mse: 266.2591 - learning_rate: 3.1250e-05
#
# ✓ Fold 3 Results:
#   Val MAE:  10.0583
#   Val RMSE: 14.8892
#   Val R²:   0.8731
#   Epochs:   53
#
# ======================================================================
# FOLD 4/5
# ======================================================================
# Train: 14186 samples, Val: 3545 samples
# Epoch 1/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - loss: 49.2839 - mae: 48.3878 - mse: 3696.8005 - val_loss: 17.6559 - val_mae: 16.9088 - val_mse: 523.8117 - learning_rate: 0.0010
# Epoch 2/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 17.9985 - mae: 17.2807 - mse: 516.2644 - val_loss: 16.3863 - val_mae: 15.7351 - val_mse: 419.8067 - learning_rate: 0.0010
# Epoch 3/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 16.6138 - mae: 15.9812 - mse: 445.1145 - val_loss: 14.8956 - val_mae: 14.3076 - val_mse: 359.4939 - learning_rate: 0.0010
# Epoch 4/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 15.7366 - mae: 15.1537 - mse: 400.5175 - val_loss: 13.8303 - val_mae: 13.2712 - val_mse: 313.0859 - learning_rate: 0.0010
# Epoch 5/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 14.7669 - mae: 14.2096 - mse: 350.1924 - val_loss: 13.1478 - val_mae: 12.6128 - val_mse: 276.7352 - learning_rate: 0.0010
# Epoch 6/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 13.8908 - mae: 13.3605 - mse: 316.8106 - val_loss: 12.8188 - val_mae: 12.3131 - val_mse: 273.0568 - learning_rate: 0.0010
# Epoch 7/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 13.4886 - mae: 12.9852 - mse: 297.3155 - val_loss: 13.2591 - val_mae: 12.7759 - val_mse: 297.9016 - learning_rate: 0.0010
# Epoch 8/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 12.9093 - mae: 12.4271 - mse: 277.7476 - val_loss: 14.4331 - val_mae: 13.9682 - val_mse: 343.2055 - learning_rate: 0.0010
# Epoch 9/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 13.1540 - mae: 12.6899 - mse: 284.2696 - val_loss: 12.0069 - val_mae: 11.5515 - val_mse: 268.5492 - learning_rate: 0.0010
# Epoch 10/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 12.6974 - mae: 12.2424 - mse: 271.7830 - val_loss: 12.7418 - val_mae: 12.3035 - val_mse: 267.0629 - learning_rate: 0.0010
# Epoch 11/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 12.1285 - mae: 11.6889 - mse: 246.7164 - val_loss: 13.2759 - val_mae: 12.8432 - val_mse: 325.5093 - learning_rate: 0.0010
# Epoch 12/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 12.1810 - mae: 11.7498 - mse: 253.0017 - val_loss: 12.4107 - val_mae: 11.9924 - val_mse: 280.7862 - learning_rate: 0.0010
# Epoch 13/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 11.8447 - mae: 11.4270 - mse: 239.0375 - val_loss: 12.2865 - val_mae: 11.8763 - val_mse: 293.0033 - learning_rate: 0.0010
# Epoch 14/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 11.6984 - mae: 11.2862 - mse: 234.4498 - val_loss: 13.2322 - val_mae: 12.8309 - val_mse: 299.6694 - learning_rate: 0.0010
# Epoch 15/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 11.7395 - mae: 11.3358 - mse: 235.6613 - val_loss: 12.9284 - val_mae: 12.5316 - val_mse: 302.1518 - learning_rate: 0.0010
# Epoch 16/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 11.6255 - mae: 11.2248 - mse: 231.8566 - val_loss: 13.5308 - val_mae: 13.1374 - val_mse: 325.2389 - learning_rate: 0.0010
# Epoch 17/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 11.4304 - mae: 11.0331 - mse: 230.1243 - val_loss: 13.6460 - val_mae: 13.2619 - val_mse: 317.9617 - learning_rate: 0.0010
# Epoch 18/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 11.0921 - mae: 10.7049 - mse: 213.7570 - val_loss: 12.9745 - val_mae: 12.6074 - val_mse: 303.4155 - learning_rate: 5.0000e-04
# Epoch 19/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 10.8187 - mae: 10.4510 - mse: 208.4166 - val_loss: 12.9249 - val_mae: 12.5781 - val_mse: 296.1665 - learning_rate: 5.0000e-04
# Epoch 20/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 10.7114 - mae: 10.3635 - mse: 202.3690 - val_loss: 12.6427 - val_mae: 12.3128 - val_mse: 309.5290 - learning_rate: 5.0000e-04
# Epoch 21/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.7546 - mae: 10.4232 - mse: 209.1721 - val_loss: 13.3680 - val_mae: 13.0549 - val_mse: 325.0424 - learning_rate: 5.0000e-04
# Epoch 22/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 10.7556 - mae: 10.4374 - mse: 204.1123 - val_loss: 12.5207 - val_mae: 12.2175 - val_mse: 301.9879 - learning_rate: 5.0000e-04
# Epoch 23/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.6562 - mae: 10.3488 - mse: 204.2837 - val_loss: 12.7026 - val_mae: 12.4133 - val_mse: 311.7832 - learning_rate: 5.0000e-04
# Epoch 24/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 10.5798 - mae: 10.2842 - mse: 202.0391 - val_loss: 13.2317 - val_mae: 12.9506 - val_mse: 328.5567 - learning_rate: 5.0000e-04
# Epoch 25/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 10.5521 - mae: 10.2656 - mse: 198.6992 - val_loss: 13.2173 - val_mae: 12.9454 - val_mse: 324.2291 - learning_rate: 5.0000e-04
# Epoch 26/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 10.4777 - mae: 10.2003 - mse: 198.9743 - val_loss: 13.3653 - val_mae: 13.1028 - val_mse: 334.5038 - learning_rate: 2.5000e-04
# Epoch 27/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.1345 - mae: 9.8653 - mse: 186.2259 - val_loss: 13.0040 - val_mae: 12.7506 - val_mse: 315.4850 - learning_rate: 2.5000e-04
# Epoch 28/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 10.3625 - mae: 10.1020 - mse: 196.1756 - val_loss: 12.6773 - val_mae: 12.4314 - val_mse: 301.4418 - learning_rate: 2.5000e-04
# Epoch 29/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 10.2829 - mae: 10.0304 - mse: 196.8139 - val_loss: 12.8227 - val_mae: 12.5847 - val_mse: 307.4707 - learning_rate: 2.5000e-04
# Epoch 30/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 10.1696 - mae: 9.9254 - mse: 187.8254 - val_loss: 13.1197 - val_mae: 12.8888 - val_mse: 320.0828 - learning_rate: 2.5000e-04
# Epoch 31/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 10.2090 - mae: 9.9689 - mse: 197.5049 - val_loss: 13.2287 - val_mae: 13.0043 - val_mse: 322.9352 - learning_rate: 2.5000e-04
# Epoch 32/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 10.2722 - mae: 10.0407 - mse: 194.4703 - val_loss: 13.1228 - val_mae: 12.9040 - val_mse: 330.5566 - learning_rate: 2.5000e-04
# Epoch 33/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 10.0958 - mae: 9.8689 - mse: 188.8614 - val_loss: 13.4468 - val_mae: 13.2343 - val_mse: 333.0778 - learning_rate: 2.5000e-04
# Epoch 34/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.9915 - mae: 9.7709 - mse: 183.4041 - val_loss: 13.2453 - val_mae: 13.0364 - val_mse: 329.7266 - learning_rate: 1.2500e-04
#
# ✓ Fold 4 Results:
#   Val MAE:  11.5515
#   Val RMSE: 16.3875
#   Val R²:   0.8463
#   Epochs:   34
#
# ======================================================================
# FOLD 5/5
# ======================================================================
# Train: 14184 samples, Val: 3547 samples
# Epoch 1/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - loss: 46.1695 - mae: 45.2505 - mse: 3358.0891 - val_loss: 14.5591 - val_mae: 13.7143 - val_mse: 321.6770 - learning_rate: 0.0010
# Epoch 2/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 17.4650 - mae: 16.6359 - mse: 494.8057 - val_loss: 14.4140 - val_mae: 13.6268 - val_mse: 330.1400 - learning_rate: 0.0010
# Epoch 3/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 16.4846 - mae: 15.7097 - mse: 442.4215 - val_loss: 13.9448 - val_mae: 13.1719 - val_mse: 292.0693 - learning_rate: 0.0010
# Epoch 4/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 16.3251 - mae: 15.5501 - mse: 424.0870 - val_loss: 12.8470 - val_mae: 12.0688 - val_mse: 263.5053 - learning_rate: 0.0010
# Epoch 5/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 14.9889 - mae: 14.2189 - mse: 360.7147 - val_loss: 13.2579 - val_mae: 12.5129 - val_mse: 295.6999 - learning_rate: 0.0010
# Epoch 6/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 14.5032 - mae: 13.7635 - mse: 342.6138 - val_loss: 12.8796 - val_mae: 12.1544 - val_mse: 282.3535 - learning_rate: 0.0010
# Epoch 7/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 13.7293 - mae: 13.0095 - mse: 303.9235 - val_loss: 12.8635 - val_mae: 12.1626 - val_mse: 272.1455 - learning_rate: 0.0010
# Epoch 8/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 13.3379 - mae: 12.6376 - mse: 289.7723 - val_loss: 12.7042 - val_mae: 12.0143 - val_mse: 272.3195 - learning_rate: 0.0010
# Epoch 9/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 12.7079 - mae: 12.0199 - mse: 264.5712 - val_loss: 12.5946 - val_mae: 11.9165 - val_mse: 293.9952 - learning_rate: 0.0010
# Epoch 10/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 12.7251 - mae: 12.0448 - mse: 265.7177 - val_loss: 13.4376 - val_mae: 12.7666 - val_mse: 277.9915 - learning_rate: 0.0010
# Epoch 11/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 12.4058 - mae: 11.7358 - mse: 250.5651 - val_loss: 12.0483 - val_mae: 11.3877 - val_mse: 286.3412 - learning_rate: 0.0010
# Epoch 12/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 12.1633 - mae: 11.5039 - mse: 242.3891 - val_loss: 13.0985 - val_mae: 12.4493 - val_mse: 262.3763 - learning_rate: 0.0010
# Epoch 13/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 11.7534 - mae: 11.1046 - mse: 227.5643 - val_loss: 12.4142 - val_mae: 11.7847 - val_mse: 272.5758 - learning_rate: 0.0010
# Epoch 14/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 11.6036 - mae: 10.9701 - mse: 220.5664 - val_loss: 13.1178 - val_mae: 12.4973 - val_mse: 290.7657 - learning_rate: 0.0010
# Epoch 15/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 11.7010 - mae: 11.0813 - mse: 220.1778 - val_loss: 12.5222 - val_mae: 11.9161 - val_mse: 274.4335 - learning_rate: 0.0010
# Epoch 16/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 11.3835 - mae: 10.7724 - mse: 211.3133 - val_loss: 13.0041 - val_mae: 12.4055 - val_mse: 297.7218 - learning_rate: 0.0010
# Epoch 17/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 11.3682 - mae: 10.7666 - mse: 213.5542 - val_loss: 13.0424 - val_mae: 12.4478 - val_mse: 288.5912 - learning_rate: 0.0010
# Epoch 18/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 11.0098 - mae: 10.4127 - mse: 199.3660 - val_loss: 12.4594 - val_mae: 11.8712 - val_mse: 286.3259 - learning_rate: 0.0010
# Epoch 19/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 11.0527 - mae: 10.4630 - mse: 201.2717 - val_loss: 12.8359 - val_mae: 12.2610 - val_mse: 300.7009 - learning_rate: 0.0010
# Epoch 20/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 10.7464 - mae: 10.1687 - mse: 186.9959 - val_loss: 12.1848 - val_mae: 11.6268 - val_mse: 272.7514 - learning_rate: 5.0000e-04
# Epoch 21/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.2356 - mae: 9.6768 - mse: 173.5972 - val_loss: 12.2368 - val_mae: 11.6992 - val_mse: 275.9495 - learning_rate: 5.0000e-04
# Epoch 22/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 10.4257 - mae: 9.8882 - mse: 183.4380 - val_loss: 11.7660 - val_mae: 11.2477 - val_mse: 266.8859 - learning_rate: 5.0000e-04
# Epoch 23/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.4517 - mae: 9.9330 - mse: 183.0390 - val_loss: 12.3417 - val_mae: 11.8397 - val_mse: 283.9896 - learning_rate: 5.0000e-04
# Epoch 24/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 10.1770 - mae: 9.6743 - mse: 173.0444 - val_loss: 12.0347 - val_mae: 11.5493 - val_mse: 294.5346 - learning_rate: 5.0000e-04
# Epoch 25/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.2349 - mae: 9.7491 - mse: 176.3784 - val_loss: 11.3947 - val_mae: 10.9106 - val_mse: 275.0416 - learning_rate: 5.0000e-04
# Epoch 26/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 10.2044 - mae: 9.7338 - mse: 175.6423 - val_loss: 11.6388 - val_mae: 11.1841 - val_mse: 262.8293 - learning_rate: 5.0000e-04
# Epoch 27/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 10.2269 - mae: 9.7707 - mse: 177.6027 - val_loss: 12.2539 - val_mae: 11.8081 - val_mse: 271.9890 - learning_rate: 5.0000e-04
# Epoch 28/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 10.2191 - mae: 9.7734 - mse: 179.0919 - val_loss: 11.4254 - val_mae: 10.9933 - val_mse: 274.5556 - learning_rate: 5.0000e-04
# Epoch 29/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 10.0595 - mae: 9.6262 - mse: 172.1456 - val_loss: 12.3882 - val_mae: 11.9697 - val_mse: 297.6139 - learning_rate: 5.0000e-04
# Epoch 30/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 10.0054 - mae: 9.5831 - mse: 172.3447 - val_loss: 11.8683 - val_mae: 11.4624 - val_mse: 276.9353 - learning_rate: 5.0000e-04
# Epoch 31/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - loss: 9.9210 - mae: 9.5135 - mse: 169.7982 - val_loss: 11.7713 - val_mae: 11.3806 - val_mse: 269.0815 - learning_rate: 5.0000e-04
# Epoch 32/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 9.8617 - mae: 9.4681 - mse: 167.9899 - val_loss: 11.9430 - val_mae: 11.5624 - val_mse: 281.0298 - learning_rate: 5.0000e-04
# Epoch 33/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.9559 - mae: 9.5720 - mse: 172.6475 - val_loss: 12.2903 - val_mae: 11.9202 - val_mse: 282.5247 - learning_rate: 5.0000e-04
# Epoch 34/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 9.8387 - mae: 9.4631 - mse: 170.7543 - val_loss: 12.2426 - val_mae: 11.8819 - val_mse: 291.7548 - learning_rate: 2.5000e-04
# Epoch 35/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.5847 - mae: 9.2193 - mse: 159.4393 - val_loss: 11.4558 - val_mae: 11.1044 - val_mse: 270.7872 - learning_rate: 2.5000e-04
# Epoch 36/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 9.4973 - mae: 9.1423 - mse: 159.4914 - val_loss: 12.0450 - val_mae: 11.7053 - val_mse: 288.3389 - learning_rate: 2.5000e-04
# Epoch 37/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.4784 - mae: 9.1320 - mse: 156.4048 - val_loss: 11.9326 - val_mae: 11.6002 - val_mse: 280.8136 - learning_rate: 2.5000e-04
# Epoch 38/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 9.4133 - mae: 9.0773 - mse: 157.1370 - val_loss: 11.5736 - val_mae: 11.2503 - val_mse: 272.7574 - learning_rate: 2.5000e-04
# Epoch 39/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 9.5466 - mae: 9.2177 - mse: 161.8440 - val_loss: 11.7366 - val_mae: 11.4206 - val_mse: 277.7557 - learning_rate: 2.5000e-04
# Epoch 40/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 9.3689 - mae: 9.0485 - mse: 157.1670 - val_loss: 11.9515 - val_mae: 11.6450 - val_mse: 278.1159 - learning_rate: 2.5000e-04
# Epoch 41/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.5295 - mae: 9.2156 - mse: 161.7562 - val_loss: 11.4887 - val_mae: 11.1865 - val_mse: 281.2885 - learning_rate: 2.5000e-04
# Epoch 42/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 9.4470 - mae: 9.1410 - mse: 160.3235 - val_loss: 12.0094 - val_mae: 11.7157 - val_mse: 279.9090 - learning_rate: 1.2500e-04
# Epoch 43/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 9.4414 - mae: 9.1406 - mse: 159.4243 - val_loss: 11.5121 - val_mae: 11.2233 - val_mse: 279.3862 - learning_rate: 1.2500e-04
# Epoch 44/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.3601 - mae: 9.0645 - mse: 157.7537 - val_loss: 11.6268 - val_mae: 11.3429 - val_mse: 271.4777 - learning_rate: 1.2500e-04
# Epoch 45/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.3897 - mae: 9.0978 - mse: 159.9628 - val_loss: 11.6306 - val_mae: 11.3517 - val_mse: 290.1475 - learning_rate: 1.2500e-04
# Epoch 46/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 9.3515 - mae: 9.0661 - mse: 157.7506 - val_loss: 11.6939 - val_mae: 11.4208 - val_mse: 277.6233 - learning_rate: 1.2500e-04
# Epoch 47/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 9.3214 - mae: 9.0396 - mse: 158.4773 - val_loss: 11.5042 - val_mae: 11.2337 - val_mse: 274.7385 - learning_rate: 1.2500e-04
# Epoch 48/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 9.2557 - mae: 8.9791 - mse: 156.7352 - val_loss: 11.7154 - val_mae: 11.4527 - val_mse: 273.3682 - learning_rate: 1.2500e-04
# Epoch 49/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 9.1136 - mae: 8.8426 - mse: 148.0268 - val_loss: 11.6236 - val_mae: 11.3644 - val_mse: 265.3482 - learning_rate: 1.2500e-04
# Epoch 50/150
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 9.1080 - mae: 8.8399 - mse: 151.6152 - val_loss: 11.8135 - val_mae: 11.5563 - val_mse: 275.3954 - learning_rate: 6.2500e-05
#
# ✓ Fold 5 Results:
#   Val MAE:  10.9106
#   Val RMSE: 16.5844
#   Val R²:   0.8425
#   Epochs:   50

# %%
# Cross-validation summary
cv_mae = [s['mae'] for s in fold_val_scores]
cv_rmse = [s['rmse'] for s in fold_val_scores]
cv_r2 = [s['r2'] for s in fold_val_scores]

print(f"Cross-Validation Results:")
print(f"  MAE:  {np.mean(cv_mae):.4f} ± {np.std(cv_mae):.4f}")
print(f"  RMSE: {np.mean(cv_rmse):.4f} ± {np.std(cv_rmse):.4f}")
print(f"  R²:   {np.mean(cv_r2):.4f} ± {np.std(cv_r2):.4f}")

# Select best model
best_fold_idx = np.argmin(cv_mae)
best_model = fold_models[best_fold_idx]
print(f"\n✓ Best model: Fold {best_fold_idx + 1}")

# Predict on test set
y_test_pred_all = best_model.predict(X_test, verbose=0).flatten()
y_test_pred_all = np.clip(y_test_pred_all, 0, None)

# Aggregate per engine (use LAST window prediction)
unique_test_engines = sorted(set(test_engine_ids))
y_test_final = []
y_pred_final = []

for engine_id in unique_test_engines:
    engine_mask = test_engine_ids == engine_id
    engine_predictions = y_test_pred_all[engine_mask]

    # Use last prediction
    y_pred_final.append(engine_predictions[-1])

    # Get true RUL
    true_rul = df_test_RUL.iloc[int(engine_id) - 1]['RUL']
    y_test_final.append(true_rul)

y_test_final = np.array(y_test_final)
y_pred_final = np.array(y_pred_final)

# Calculate metrics
test_mae = mean_absolute_error(y_test_final, y_pred_final)
test_rmse = np.sqrt(mean_squared_error(y_test_final, y_pred_final))
test_r2 = r2_score(y_test_final, y_pred_final)
test_mape = np.mean(np.abs((y_test_final - y_pred_final) / (y_test_final + 1e-8))) * 100

print(f"\n✓ Test Set Results ({len(y_test_final)} engines):")
print(f"  MAE:  {test_mae:.4f} cycles")
print(f"  RMSE: {test_rmse:.4f} cycles")
print(f"  R²:   {test_r2:.4f}")
print(f"  MAPE: {test_mape:.2f}%")

print(f"\n  Diagnostics:")
print(f"    Mean pred: {y_pred_final.mean():.2f}, Mean actual: {y_test_final.mean():.2f}")
print(f"    Std pred:  {y_pred_final.std():.2f}, Std actual:  {y_test_final.std():.2f}")
# Out:
# Cross-Validation Results:
#   MAE:  11.3602 ± 0.9889
#   RMSE: 16.8276 ± 1.2888
#   R²:   0.8370 ± 0.0248
#
# ✓ Best model: Fold 3
#
# ✓ Test Set Results (100 engines):
#   MAE:  14.8927 cycles
#   RMSE: 19.6517 cycles
#   R²:   0.7764
#   MAPE: 22.89%
#
#   Diagnostics:
#     Mean pred: 76.29, Mean actual: 75.52
#     Std pred:  39.48, Std actual:  41.56

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Training history
ax = axes[0, 0]
for i, history in enumerate(fold_histories, 1):
    ax.plot(history.history['loss'], label=f'Fold {i}', alpha=0.6)
ax.set_title('Training Loss', fontweight='bold')
ax.set_xlabel('Epoch')
ax.set_ylabel('Huber Loss')
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)

# 2. Validation history
ax = axes[0, 1]
for i, history in enumerate(fold_histories, 1):
    ax.plot(history.history['val_loss'], label=f'Fold {i}', alpha=0.6)
ax.set_title('Validation Loss', fontweight='bold')
ax.set_xlabel('Epoch')
ax.set_ylabel('Huber Loss')
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)

# 3. MAE history
ax = axes[0, 2]
for i, history in enumerate(fold_histories, 1):
    ax.plot(history.history['val_mae'], label=f'Fold {i}', alpha=0.6)
ax.set_title('Validation MAE', fontweight='bold')
ax.set_xlabel('Epoch')
ax.set_ylabel('MAE')
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)

# 4. Predictions vs Actual
ax = axes[1, 0]
ax.scatter(y_test_final, y_pred_final, alpha=0.6, s=60, edgecolors='black', linewidth=0.5)
max_val = max(y_test_final.max(), y_pred_final.max())
ax.plot([0, max_val], [0, max_val], 'r--', lw=2, label='Perfect')
ax.set_xlabel('Actual RUL')
ax.set_ylabel('Predicted RUL')
ax.set_title(f'Predictions vs Actual\nMAE: {test_mae:.2f}, R²: {test_r2:.3f}', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 5. Error distribution
ax = axes[1, 1]
errors = y_pred_final - y_test_final
ax.hist(errors, bins=30, edgecolor='black', alpha=0.7, color='steelblue')
ax.axvline(x=0, color='r', linestyle='--', lw=2, label='Zero Error')
ax.axvline(x=np.mean(errors), color='green', linestyle='--', lw=2, label=f'Mean: {np.mean(errors):.2f}')
ax.set_xlabel('Error (Predicted - Actual)')
ax.set_ylabel('Frequency')
ax.set_title('Error Distribution', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 6. Sample predictions
ax = axes[1, 2]
n_samples = min(30, len(y_test_final))
sample_indices = np.linspace(0, len(y_test_final)-1, n_samples, dtype=int)
x_pos = np.arange(n_samples)
ax.plot(x_pos, y_test_final[sample_indices], 'o-', label='Actual', markersize=6, linewidth=2)
ax.plot(x_pos, y_pred_final[sample_indices], 's-', label='Predicted', markersize=6, linewidth=2)
ax.set_xlabel('Engine Index')
ax.set_ylabel('RUL (cycles)')
ax.set_title(f'Sample Predictions ({n_samples} engines)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('gated_ensemble_bilstm_results.png', dpi=300, bbox_inches='tight')
print("✓ Saved: gated_ensemble_bilstm_results.png")
plt.show()
# Out:
# ✓ Saved: gated_ensemble_bilstm_results.png

# %%
print(f"\n✓ Training Complete!")
print(f"\nArchitecture: Gated Ensemble BiLSTM (NOVEL)")
print(f"  - 3 parallel branches (LSTM, GRU, CNN)")
print(f"  - Learned gating mechanism")
print(f"  - 2 BiLSTM integration layers")

print(f"\nPerformance:")
print(f"  Cross-Validation MAE:  {np.mean(cv_mae):.4f} ± {np.std(cv_mae):.4f}")
print(f"  Cross-Validation R²:   {np.mean(cv_r2):.4f} ± {np.std(cv_r2):.4f}")
print(f"  Test MAE:  {test_mae:.4f}")
print(f"  Test RMSE: {test_rmse:.4f}")
print(f"  Test R²:   {test_r2:.4f}")

# Performance assessment
if test_r2 >= 0.85:
    print("\n  🏆🏆 OUTSTANDING performance (R² ≥ 0.85)")
elif test_r2 >= 0.80:
    print("\n  🏆 EXCELLENT performance (0.80 ≤ R² < 0.85)")
elif test_r2 >= 0.70:
    print("\n  ✅ GOOD performance (0.70 ≤ R² < 0.80)")
else:
    print("\n  ⚠️  MODERATE performance (R² < 0.70)")
# Out:
# ✓ Training Complete!
#
# Architecture: Gated Ensemble BiLSTM (NOVEL)
#   - 3 parallel branches (LSTM, GRU, CNN)
#   - Learned gating mechanism
#   - 2 BiLSTM integration layers
#
# Performance:
#   Cross-Validation MAE:  11.3602 ± 0.9889
#   Cross-Validation R²:   0.8370 ± 0.0248
#   Test MAE:  14.8927
#   Test RMSE: 19.6517
#   Test R²:   0.7764
#
#   ✅ GOOD performance (0.70 ≤ R² < 0.80)
